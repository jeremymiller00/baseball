# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pymongo import MongoClient
from bson import Code
import pandas as pd
pd.set_option('display.max_columns', 2000)
pd.set_option('display.max_rows', 2000)

# %%
df = pd.read_csv("../data/lahman_data/baseballdatabank-2019.2/core/Parks.csv")

# %%
df.sample(20)
# Out:
#     park.key              park.name       park.alias          city state  \
# 31     CAN01          Mahaffey Park     Pastime Park        Canton    OH
# 167    PHI05          Keystone Park              NaN  Philadelphia    PA
# 28     BUF02         Olympic Park I              NaN       Buffalo    NY
# 128    MIL06            Miller Park              NaN     Milwaukee    WI
# 11     BAL04             Belair Lot              NaN     Baltimore    MD
# 63     COL01      Recreation Park I              NaN      Columbus    OH
# 211    STL07   Sportsman's Park III  Busch Stadium I     St. Louis    MO
# 83     GRA01            Ramona Park              NaN  Grand Rapids    MI
# 214    STL10      Busch Stadium III              NaN     St. Louis    MO
# 93     IND02  Seventh Street Park I              NaN  Indianapolis    IN
# 209    STL05          Robison Field              NaN     St. Louis    MO
# 136    NEW01  Howard Avenue Grounds    Brewster Park     New Haven    CT
# 65     COL03            Neil Park I              NaN      Columbus    OH
# 193    ROC03  Ontario Beach Grounds              NaN     Rochester    NY
# 191    ROC01         Culver Field I              NaN     Rochester    NY
# 21     BOS03   South End Grounds II              NaN        Boston    MA
# 147    NYC08     Washington Park II              NaN      Brooklyn    NY
# 119    MAS01    Long Island Grounds              NaN       Maspeth    NY
# 64     COL02     Recreation Park II              NaN      Columbus    OH
# 206    STL02      Grand Avenue Park              NaN     St. Louis    MO
#
#     country
# 31       US
# 167      US
# 28       US
# 128      US
# 11       US
# 63       US
# 211      US
# 83       US
# 214      US
# 93       US
# 209      US
# 136      US
# 65       US
# 193      US
# 191      US
# 21       US
# 147      US
# 119      US
# 64       US
# 206      US
