# %% [markdown]
# # Load Entire Retrosheet Database into a Pandas Dataframe

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import sys
sys.path.append('..')
import src.eda_tools as et

# %%
# from pymongo import MongoClient
# client = MongoClient('localhost', 27017)
# db = client['retrosheet']

# %%
# cursor = db[c1].find()

# %%
# len(list(cursor))

# %%
data = et.read_database('retrosheet')
# Out:
# ../src/eda_tools.py:67: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat(dfs)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 381350 entries, 0 to 12765
# Data columns (total 38 columns):
# attendance       2429 non-null object
# batting_order    76038 non-null object
# bottom           222052 non-null object
# comment          20106 non-null object
# count            222052 non-null object
# date             2429 non-null object
# daynight         2429 non-null object
# entry_type       381350 non-null object
# event            222052 non-null object
# fieldcond        2429 non-null object
# game_id          381350 non-null object
# home_team        76038 non-null object
# hometeam         2429 non-null object
# howscored        2429 non-null object
# inning           222052 non-null object
# lp               2429 non-null object
# name             76038 non-null object
# number           2429 non-null object
# oscorer          2429 non-null object
# pitches          224481 non-null object
# player_id        298090 non-null object
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.distplot(data['timeofgame'].dropna().astype('int'), color='b')

# %%
fig, ax = plt.subplots(figsize=(12,8))
src=data[ (data['pitches'] != '') & (data['pitches'] != 'pitches')]['pitches'].dropna().value_counts()[:10]
sns.barplot(src.index, src.values)

# %%
dates = pd.to_datetime(data['date'].dropna())

# %%
years = set()
for d in dates:
    years.add(d.year)

# %%
years
# Out:
# {2019}

# %%
max(dates)
# Out:
# Timestamp('2019-09-29 00:00:00')
